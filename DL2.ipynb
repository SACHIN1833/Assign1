# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Example text sequences
texts = [
    "I love deep learning",
    "Autoencoders are amazing",
    "Text generation is fun",
    "Neural networks are powerful"
]

# Tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
word_index = tokenizer.word_index

# Get vocabulary size
vocab_size = len(word_index) + 1

# Pad sequences to have the same length
max_sequence_len = max([len(seq) for seq in sequences])
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_len, padding='post')

# %%
# Hyperparameters
embedding_dim = 50  # Size of word embeddings
latent_dim = 100    # Size of the latent space (output of encoder)

# Encoder
encoder_inputs = Input(shape=(max_sequence_len,))
embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_sequence_len)
embedded_inputs = embedding_layer(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_sequences=False, return_state=True)
_, state_h, state_c = encoder_lstm(embedded_inputs)

# Encoder output: the latent representation (state_h and state_c)

# Decoder
decoder_inputs = Input(shape=(max_sequence_len,))
decoder_embedding = embedding_layer(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=False)
decoder_outputs = decoder_lstm(decoder_embedding, initial_state=[state_h, state_c])

# Output layer: Predict the next word in the sequence
decoder_dense = Dense(vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Build the autoencoder model
autoencoder = Model([encoder_inputs, decoder_inputs], decoder_outputs)
autoencoder.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

autoencoder.summary()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 4)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer (InputLayer)      │ (None, 4)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding (Embedding)         │ (None, 4, 50)             │             750 │ input_layer[0][0],         │
# │                               │                           │                 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ [(None, 100), (None,      │          60,400 │ embedding[0][0]            │
# │                               │ 100), (None, 100)]        │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_1 (LSTM)                 │ (None, 4, 100)            │          60,400 │ embedding[1][0],           │
# │                               │                           │                 │ lstm[0][1], lstm[0][2]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 4, 15)             │           1,515 │ lstm_1[0][0]               │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 123,065 (480.72 KB)
#  Trainable params: 123,065 (480.72 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Create input-output pairs
X = padded_sequences
y = np.expand_dims(padded_sequences, -1)  # Target sequences (same as inputs)

# Train the autoencoder
history = autoencoder.fit([X, X], y, batch_size=16, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 2.7053 - val_loss: 2.7112
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 2.6991 - val_loss: 2.7148
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 2.6928 - val_loss: 2.7185
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 2.6863 - val_loss: 2.7223
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 2.6796 - val_loss: 2.7263
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 2.6724 - val_loss: 2.7304
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 2.6649 - val_loss: 2.7348
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 2.6567 - val_loss: 2.7394
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - loss: 2.6479 - val_loss: 2.7442
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 2.6384 - val_loss: 2.7494
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - loss: 2.6279 - val_loss: 2.7550
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 2.6164 - val_loss: 2.7610
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - loss: 2.6037 - val_loss: 2.7674
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 2.5895 - val_loss: 2.7744
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 2.5738 - val_loss: 2.7820
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 2.5562 - val_loss: 2.7902
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 2.5365 - val_loss: 2.7992
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 2.5144 - val_loss: 2.8091
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 2.4895 - val_loss: 2.8200
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 2.4614 - val_loss: 2.8320
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - loss: 2.4296 - val_loss: 2.8452
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 2.3935 - val_loss: 2.8599
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - loss: 2.3528 - val_loss: 2.8764
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 2.3067 - val_loss: 2.8948
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 2.2546 - val_loss: 2.9156
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 2.1962 - val_loss: 2.9392
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 2.1309 - val_loss: 2.9661
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 2.0589 - val_loss: 2.9972
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.9806 - val_loss: 3.0331
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8971 - val_loss: 3.0751
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8106 - val_loss: 3.1245
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.7236 - val_loss: 3.1827
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.6391 - val_loss: 3.2516
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.5595 - val_loss: 3.3326
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.4862 - val_loss: 3.4273
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.4195 - val_loss: 3.5366
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.3584 - val_loss: 3.6614
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.3014 - val_loss: 3.8021
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 1.2470 - val_loss: 3.9584
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 1.1937 - val_loss: 4.1295
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 1.1408 - val_loss: 4.3140
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 1.0880 - val_loss: 4.5107
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 1.0367 - val_loss: 4.7188
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.9890 - val_loss: 4.9388
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 0.9469 - val_loss: 5.1703
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 0.9105 - val_loss: 5.4113
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 0.8774 - val_loss: 5.6563
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 0.8436 - val_loss: 5.8993
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.8066 - val_loss: 6.1355
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - loss: 0.7673 - val_loss: 6.3622
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - loss: 0.7290 - val_loss: 6.5784
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - loss: 0.6945 - val_loss: 6.7839
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - loss: 0.6637 - val_loss: 6.9788
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - loss: 0.6343 - val_loss: 7.1631
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - loss: 0.6046 - val_loss: 7.3359
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - loss: 0.5749 - val_loss: 7.4961
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - loss: 0.5461 - val_loss: 7.6422
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.5187 - val_loss: 7.7739
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.4922 - val_loss: 7.8924
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.4661 - val_loss: 8.0010
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.4410 - val_loss: 8.1046
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.4172 - val_loss: 8.2078
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.3950 - val_loss: 8.3116
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - loss: 0.3739 - val_loss: 8.4136
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.3541 - val_loss: 8.5091
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.3356 - val_loss: 8.5941
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - loss: 0.3182 - val_loss: 8.6677
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.3014 - val_loss: 8.7335
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.2852 - val_loss: 8.7981
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.2702 - val_loss: 8.8673
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.2562 - val_loss: 8.9436
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.2429 - val_loss: 9.0245
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.2300 - val_loss: 9.1046
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.2177 - val_loss: 9.1788
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 0.2059 - val_loss: 9.2446
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.1944 - val_loss: 9.3027
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.1834 - val_loss: 9.3550
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.1730 - val_loss: 9.4038
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 0.1635 - val_loss: 9.4504
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.1547 - val_loss: 9.4956
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.1463 - val_loss: 9.5394
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.1385 - val_loss: 9.5818
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.1312 - val_loss: 9.6230
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.1245 - val_loss: 9.6633
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1182 - val_loss: 9.7026
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.1122 - val_loss: 9.7407
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.1066 - val_loss: 9.7774
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.1014 - val_loss: 9.8125
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0966 - val_loss: 9.8456
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0920 - val_loss: 9.8767
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0876 - val_loss: 9.9056
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.0835 - val_loss: 9.9324
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0796 - val_loss: 9.9572
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - loss: 0.0761 - val_loss: 9.9799
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - loss: 0.0727 - val_loss: 10.0005
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0695 - val_loss: 10.0192
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 0.0666 - val_loss: 10.0363
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.0638 - val_loss: 10.0522
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0612 - val_loss: 10.0675
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0588 - val_loss: 10.0828

# %%
def generate_text(seed_text, num_words, max_sequence_len, model, tokenizer):
    for _ in range(num_words):
        # Tokenize the seed text
        sequence = tokenizer.texts_to_sequences([seed_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_sequence_len, padding='post')
        
        # Predict the next word
        predicted = model.predict([sequence, sequence], verbose=0)
        predicted_word_idx = np.argmax(predicted[0][-1])

        # Convert predicted index to word
        word = tokenizer.index_word.get(predicted_word_idx)
        if word is None:
            break
        seed_text += ' ' + word
    return seed_text

# Generate a text sequence
seed_text = "I love"
generated_text = generate_text(seed_text, num_words=5, max_sequence_len=max_sequence_len, model=autoencoder, tokenizer=tokenizer)
print("Generated Text:", generated_text)
# Out:
# Generated Text: I love deep learning learning learning learning
